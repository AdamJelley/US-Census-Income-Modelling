# %% [markdown]
# # Dataiku Technical Assessment - US Census Income Modelling

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

from sklearn.feature_selection import chi2

from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV

pd.options.display.max_columns = 50

# %%
us_census_train = pd.read_csv('us_census_full/census_income_learn.csv', 
                              header = None, skipinitialspace = True, na_values= 'Not in universe')
us_census_test = pd.read_csv('us_census_full/census_income_test.csv', 
                              header = None, skipinitialspace = True, na_values= 'Not in universe')

# %%
with open('us_census_full/census_income_metadata.txt', 'r') as f:
    for lineNo, line in enumerate(f.readlines()):
        print(lineNo, line)
# Out:
# 0 | This data was extracted from the census bureau database found at
#
# 1 | http://www.census.gov/ftp/pub/DES/www/welcome.html
#
# 2 | Donor: Terran Lane and Ronny Kohavi
#
# 3 |        Data Mining and Visualization
#
# 4 |        Silicon Graphics.
#
# 5 |        e-mail: terran@ecn.purdue.edu, ronnyk@sgi.com for questions.
#
# 6 |
#
# 7 | The data was split into train/test in approximately 2/3, 1/3
#
# 8 | proportions using MineSet's MIndUtil mineset-to-mlc.
#
# 9 |
#
# 10 | Prediction task is to determine the income level for the person
#
# 11 | represented by the record.  Incomes have been binned at the $50K
#
# 12 | level to present a binary classification problem, much like the
#
# 13 | original UCI/ADULT database.  The goal field of this data, however,
#
# 14 | was drawn from the "total person income" field rather than the
#
# 15 | "adjusted gross income" and may, therefore, behave differently than the
#
# 16 | orginal ADULT goal field.
#
# 17 |
#
# 18 | More information detailing the meaning of the attributes can be
#
# 19 | found in http://www.bls.census.gov/cps/cpsmain.htm
#
# 20 | To make use of the data descriptions at this site, the following mappings
#
# 21 | to the Census Bureau's internal database column names will be needed:
#
# 22 |
#
# 23 | age						AAGE
#
# 24 | class of worker				ACLSWKR
#
# 25 | industry code					ADTIND
#
# 26 | occupation code				ADTOCC
#
# 27 | adjusted gross income				AGI
#
# 28 | education					AHGA
#
# 29 | wage per hour					AHRSPAY
#
# 30 | enrolled in edu inst last wk			AHSCOL
#
# 31 | marital status				AMARITL
#
# 32 | major industry code				AMJIND
#
# 33 | major occupation code				AMJOCC
#
# 34 | mace						ARACE
#
# 35 | hispanic Origin				AREORGN
#
# 36 | sex						ASEX
#
# 37 | member of a labor union			AUNMEM
#
# 38 | reason for unemployment			AUNTYPE
#
# 39 | full or part time employment stat		AWKSTAT
#
# 40 | capital gains					CAPGAIN
#
# 41 | capital losses				CAPLOSS
#
# 42 | divdends from stocks				DIVVAL
#
# 43 | federal income tax liability			FEDTAX
#
# 44 | tax filer status				FILESTAT
#
# 45 | region of previous residence			GRINREG
#
# 46 | state of previous residence			GRINST
#
# 47 | detailed household and family stat		HHDFMX
#
# 48 | detailed household summary in household	HHDREL
#
# 49 | instance weight				MARSUPWT
#
# 50 | migration code-change in msa			MIGMTR1
#
# 51 | migration code-change in reg			MIGMTR3
#
# 52 | migration code-move within reg		MIGMTR4
#
# 53 | live in this house 1 year ago			MIGSAME
#
# 54 | migration prev res in sunbelt			MIGSUN
#
# 55 | num persons worked for employer		NOEMP
#
# 56 | family members under 18			PARENT
#
# 57 | total person earnings				PEARNVAL
#
# 58 | country of birth father			PEFNTVTY
#
# 59 | country of birth mother			PEMNTVTY
#
# 60 | country of birth self				PENATVTY
#
# 61 | citizenship					PRCITSHP
#
# 62 | total person income				PTOTVAL
#
# 63 | own business or self employed			SEOTR
#
# 64 | taxable income amount				TAXINC
#
# 65 | fill inc questionnaire for veteran's admin	VETQVA
#
# 66 | veterans benefits				VETYN
#
# 67 | weeks worked in year				WKSWORK
#
# 68 |
#
# 69 | Basic statistics for this data set:
#
# 70 |
#
# 71 | Number of instances data = 199523
#
# 72 |    Duplicate or conflicting instances : 46716
#
# 73 | Number of instances in test = 99762
#
# 74 |    Duplicate or conflicting instances : 20936
#
# 75 | Class probabilities for income-projected.test file
#
# 76 | Probability for the label '- 50000' : 93.80%
#
# 77 | Probability for the label '50000+' : 6.20%
#
# 78 | Majority accuracy: 93.80% on value - 50000
#
# 79 | Number of attributes = 40 (continuous : 7 nominal : 33)
#
# 80 | Information about .data file :
#
# 81 |   91 distinct values for attribute #0 (age) continuous
#
# 82 |    9 distinct values for attribute #1 (class of worker) nominal
#
# 83 |   52 distinct values for attribute #2 (detailed industry recode) nominal
#
# 84 |   47 distinct values for attribute #3 (detailed occupation recode) nominal
#
# 85 |   17 distinct values for attribute #4 (education) nominal
#
# 86 | 1240 distinct values for attribute #5 (wage per hour) continuous
#
# 87 |    3 distinct values for attribute #6 (enroll in edu inst last wk) nominal
#
# 88 |    7 distinct values for attribute #7 (marital stat) nominal
#
# 89 |   24 distinct values for attribute #8 (major industry code) nominal
#
# 90 |   15 distinct values for attribute #9 (major occupation code) nominal
#
# 91 |    5 distinct values for attribute #10 (race) nominal
#
# 92 |   10 distinct values for attribute #11 (hispanic origin) nominal
#
# 93 |    2 distinct values for attribute #12 (sex) nominal
#
# 94 |    3 distinct values for attribute #13 (member of a labor union) nominal
#
# 95 |    6 distinct values for attribute #14 (reason for unemployment) nominal
#
# 96 |    8 distinct values for attribute #15 (full or part time employment stat) nominal
#
# 97 |  132 distinct values for attribute #16 (capital gains) continuous
#
# 98 |  113 distinct values for attribute #17 (capital losses) continuous
#
# 99 | 1478 distinct values for attribute #18 (dividends from stocks) continuous
#
# 100 |    6 distinct values for attribute #19 (tax filer stat) nominal
#
# 101 |    6 distinct values for attribute #20 (region of previous residence) nominal
#
# 102 |   51 distinct values for attribute #21 (state of previous residence) nominal
#
# 103 |   38 distinct values for attribute #22 (detailed household and family stat) nominal
#
# 104 |    8 distinct values for attribute #23 (detailed household summary in household) nominal
#
# 105 |   10 distinct values for attribute #24 (migration code-change in msa) nominal
#
# 106 |    9 distinct values for attribute #25 (migration code-change in reg) nominal
#
# 107 |   10 distinct values for attribute #26 (migration code-move within reg) nominal
#
# 108 |    3 distinct values for attribute #27 (live in this house 1 year ago) nominal
#
# 109 |    4 distinct values for attribute #28 (migration prev res in sunbelt) nominal
#
# 110 |    7 distinct values for attribute #29 (num persons worked for employer) continuous
#
# 111 |    5 distinct values for attribute #30 (family members under 18) nominal
#
# 112 |   43 distinct values for attribute #31 (country of birth father) nominal
#
# 113 |   43 distinct values for attribute #32 (country of birth mother) nominal
#
# 114 |   43 distinct values for attribute #33 (country of birth self) nominal
#
# 115 |    5 distinct values for attribute #34 (citizenship) nominal
#
# 116 |    3 distinct values for attribute #35 (own business or self employed) nominal
#
# 117 |    3 distinct values for attribute #36 (fill inc questionnaire for veteran's admin) nominal
#
# 118 |    3 distinct values for attribute #37 (veterans benefits) nominal
#
# 119 |   53 distinct values for attribute #38 (weeks worked in year) continuous
#
# 120 |    2 distinct values for attribute #39 (year) nominal
#
# 121 |
#
# 122 |
#
# 123 | Error rates:
#
# 124 |    C4.5       	: 4.8%
#
# 125 |    C5.0		: 4.7%
#
# 126 |    C5.0 rules		: 4.7%
#
# 127 |    C5.0 boosting	: 4.6%
#
# 128 |    Naive-Bayes	: 23.2%
#
# 129 |
#
# 130 |
#
# 131 | All commas and periods were changed to spaces
#
# 132 | Colons were replaced with dashes.
#
# 133 |
#
# 134 | The instance weight indicates the number of people in the population
#
# 135 | that each record represents due to stratified sampling.
#
# 136 | To do real analysis and derive conclusions, this field must be used.
#
# 137 | This attribute should *not* be used in the classifiers, so it is
#
# 138 | set to "ignore" in this file.
#
# 139 |
#
# 140 - 50000, 50000+.
#
# 141
#
# 142 age: continuous.
#
# 143 class of worker: Not in universe, Federal government, Local government, Never worked, Private, Self-employed-incorporated, Self-employed-not incorporated, State government, Without pay.
#
# 144 detailed industry recode: 0, 40, 44, 2, 43, 47, 48, 1, 11, 19, 24, 25, 32, 33, 34, 35, 36, 37, 38, 39, 4, 42, 45, 5, 15, 16, 22, 29, 31, 50, 14, 17, 18, 28, 3, 30, 41, 46, 51, 12, 13, 21, 23, 26, 6, 7, 9, 49, 27, 8, 10, 20.
#
# 145 detailed occupation recode: 0, 12, 31, 44, 19, 32, 10, 23, 26, 28, 29, 42, 40, 34, 14, 36, 38, 2, 20, 25, 37, 41, 27, 24, 30, 43, 33, 16, 45, 17, 35, 22, 18, 39, 3, 15, 13, 46, 8, 21, 9, 4, 6, 5, 1, 11, 7.
#
# 146 education: Children, 7th and 8th grade, 9th grade, 10th grade, High school graduate, 11th grade, 12th grade no diploma, 5th or 6th grade, Less than 1st grade, Bachelors degree(BA AB BS), 1st 2nd 3rd or 4th grade, Some college but no degree, Masters degree(MA MS MEng MEd MSW MBA), Associates degree-occup /vocational, Associates degree-academic program, Doctorate degree(PhD EdD), Prof school degree (MD DDS DVM LLB JD).
#
# 147 wage per hour: continuous.
#
# 148 enroll in edu inst last wk: Not in universe, High school, College or university.
#
# 149 marital stat: Never married, Married-civilian spouse present, Married-spouse absent, Separated, Divorced, Widowed, Married-A F spouse present.
#
# 150 major industry code: Not in universe or children, Entertainment, Social services, Agriculture, Education, Public administration, Manufacturing-durable goods, Manufacturing-nondurable goods, Wholesale trade, Retail trade, Finance insurance and real estate, Private household services, Business and repair services, Personal services except private HH, Construction, Medical except hospital, Other professional services, Transportation, Utilities and sanitary services, Mining, Communications, Hospital services, Forestry and fisheries, Armed Forces.
#
# 151 major occupation code: Not in universe, Professional specialty, Other service, Farming forestry and fishing, Sales, Adm support including clerical, Protective services, Handlers equip cleaners etc , Precision production craft & repair, Technicians and related support, Machine operators assmblrs & inspctrs, Transportation and material moving, Executive admin and managerial, Private household services, Armed Forces.
#
# 152 race: White, Black, Other, Amer Indian Aleut or Eskimo, Asian or Pacific Islander.
#
# 153 hispanic origin: Mexican (Mexicano), Mexican-American, Puerto Rican, Central or South American, All other, Other Spanish, Chicano, Cuban, Do not know, NA.
#
# 154 sex: Female, Male.
#
# 155 member of a labor union: Not in universe, No, Yes.
#
# 156 reason for unemployment: Not in universe, Re-entrant, Job loser - on layoff, New entrant, Job leaver, Other job loser.
#
# 157 full or part time employment stat: Children or Armed Forces, Full-time schedules, Unemployed part- time, Not in labor force, Unemployed full-time, PT for non-econ reasons usually FT, PT for econ reasons usually PT, PT for econ reasons usually FT.
#
# 158 capital gains: continuous.
#
# 159 capital losses: continuous.
#
# 160 dividends from stocks: continuous.
#
# 161 tax filer stat: Nonfiler, Joint one under 65 & one 65+, Joint both under 65, Single, Head of household, Joint both 65+.
#
# 162 region of previous residence: Not in universe, South, Northeast, West, Midwest, Abroad.
#
# 163 state of previous residence: Not in universe, Utah, Michigan, North Carolina, North Dakota, Virginia, Vermont, Wyoming, West Virginia, Pennsylvania, Abroad, Oregon, California, Iowa, Florida, Arkansas, Texas, South Carolina, Arizona, Indiana, Tennessee, Maine, Alaska, Ohio, Montana, Nebraska, Mississippi, District of Columbia, Minnesota, Illinois, Kentucky, Delaware, Colorado, Maryland, Wisconsin, New Hampshire, Nevada, New York, Georgia, Oklahoma, New Mexico, South Dakota, Missouri, Kansas, Connecticut, Louisiana, Alabama, Massachusetts, Idaho, New Jersey.
#
# 164 detailed household and family stat: Child <18 never marr not in subfamily, Other Rel <18 never marr child of subfamily RP, Other Rel <18 never marr not in subfamily, Grandchild <18 never marr child of subfamily RP, Grandchild <18 never marr not in subfamily, Secondary individual, In group quarters, Child under 18 of RP of unrel subfamily, RP of unrelated subfamily, Spouse of householder, Householder, Other Rel <18 never married RP of subfamily, Grandchild <18 never marr RP of subfamily, Child <18 never marr RP of subfamily, Child <18 ever marr not in subfamily, Other Rel <18 ever marr RP of subfamily, Child <18 ever marr RP of subfamily, Nonfamily householder, Child <18 spouse of subfamily RP, Other Rel <18 spouse of subfamily RP, Other Rel <18 ever marr not in subfamily, Grandchild <18 ever marr not in subfamily, Child 18+ never marr Not in a subfamily, Grandchild 18+ never marr not in subfamily, Child 18+ ever marr RP of subfamily, Other Rel 18+ never marr not in subfamily, Child 18+ never marr RP of subfamily, Other Rel 18+ ever marr RP of subfamily, Other Rel 18+ never marr RP of subfamily, Other Rel 18+ spouse of subfamily RP, Other Rel 18+ ever marr not in subfamily, Child 18+ ever marr Not in a subfamily, Grandchild 18+ ever marr not in subfamily, Child 18+ spouse of subfamily RP, Spouse of RP of unrelated subfamily, Grandchild 18+ ever marr RP of subfamily, Grandchild 18+ never marr RP of subfamily, Grandchild 18+ spouse of subfamily RP.
#
# 165 detailed household summary in household: Child under 18 never married, Other relative of householder, Nonrelative of householder, Spouse of householder, Householder, Child under 18 ever married, Group Quarters- Secondary individual, Child 18 or older.
#
# 166 | instance weight: ignore.
#
# 167 instance weight: continuous.
#
# 168 migration code-change in msa: Not in universe, Nonmover, MSA to MSA, NonMSA to nonMSA, MSA to nonMSA, NonMSA to MSA, Abroad to MSA, Not identifiable, Abroad to nonMSA.
#
# 169 migration code-change in reg: Not in universe, Nonmover, Same county, Different county same state, Different state same division, Abroad, Different region, Different division same region.
#
# 170 migration code-move within reg: Not in universe, Nonmover, Same county, Different county same state, Different state in West, Abroad, Different state in Midwest, Different state in South, Different state in Northeast.
#
# 171 live in this house 1 year ago: Not in universe under 1 year old, Yes, No.
#
# 172 migration prev res in sunbelt: Not in universe, Yes, No.
#
# 173 num persons worked for employer: continuous.
#
# 174 family members under 18: Both parents present, Neither parent present, Mother only present, Father only present, Not in universe.
#
# 175 country of birth father: Mexico, United-States, Puerto-Rico, Dominican-Republic, Jamaica, Cuba, Portugal, Nicaragua, Peru, Ecuador, Guatemala, Philippines, Canada, Columbia, El-Salvador, Japan, England, Trinadad&Tobago, Honduras, Germany, Taiwan, Outlying-U S (Guam USVI etc), India, Vietnam, China, Hong Kong, Cambodia, France, Laos, Haiti, South Korea, Iran, Greece, Italy, Poland, Thailand, Yugoslavia, Holand-Netherlands, Ireland, Scotland, Hungary, Panama.
#
# 176 country of birth mother: India, Mexico, United-States, Puerto-Rico, Dominican-Republic, England, Honduras, Peru, Guatemala, Columbia, El-Salvador, Philippines, France, Ecuador, Nicaragua, Cuba, Outlying-U S (Guam USVI etc), Jamaica, South Korea, China, Germany, Yugoslavia, Canada, Vietnam, Japan, Cambodia, Ireland, Laos, Haiti, Portugal, Taiwan, Holand-Netherlands, Greece, Italy, Poland, Thailand, Trinadad&Tobago, Hungary, Panama, Hong Kong, Scotland, Iran.
#
# 177 country of birth self: United-States, Mexico, Puerto-Rico, Peru, Canada, South Korea, India, Japan, Haiti, El-Salvador, Dominican-Republic, Portugal, Columbia, England, Thailand, Cuba, Laos, Panama, China, Germany, Vietnam, Italy, Honduras, Outlying-U S (Guam USVI etc), Hungary, Philippines, Poland, Ecuador, Iran, Guatemala, Holand-Netherlands, Taiwan, Nicaragua, France, Jamaica, Scotland, Yugoslavia, Hong Kong, Trinadad&Tobago, Greece, Cambodia, Ireland.
#
# 178 citizenship: Native- Born in the United States, Foreign born- Not a citizen of U S , Native- Born in Puerto Rico or U S Outlying, Native- Born abroad of American Parent(s), Foreign born- U S citizen by naturalization.
#
# 179 own business or self employed: 0, 2, 1.
#
# 180 fill inc questionnaire for veteran's admin: Not in universe, Yes, No.
#
# 181 veterans benefits: 0, 2, 1.
#
# 182 weeks worked in year: continuous.
#
# 183 year: 94, 95.

# %%
columns = []
with open('us_census_full/census_income_metadata.txt', 'r') as f:
    for lineNo, line in enumerate(f.readlines()):
        if lineNo > 141:
            featureName = line.split(':')[0]
            featureName = featureName.replace(' ', '_')
            columns.append(featureName)
    print(columns)
# Out:
# ['age', 'class_of_worker', 'detailed_industry_recode', 'detailed_occupation_recode', 'education', 'wage_per_hour', 'enroll_in_edu_inst_last_wk', 'marital_stat', 'major_industry_code', 'major_occupation_code', 'race', 'hispanic_origin', 'sex', 'member_of_a_labor_union', 'reason_for_unemployment', 'full_or_part_time_employment_stat', 'capital_gains', 'capital_losses', 'dividends_from_stocks', 'tax_filer_stat', 'region_of_previous_residence', 'state_of_previous_residence', 'detailed_household_and_family_stat', 'detailed_household_summary_in_household', '|_instance_weight', 'instance_weight', 'migration_code-change_in_msa', 'migration_code-change_in_reg', 'migration_code-move_within_reg', 'live_in_this_house_1_year_ago', 'migration_prev_res_in_sunbelt', 'num_persons_worked_for_employer', 'family_members_under_18', 'country_of_birth_father', 'country_of_birth_mother', 'country_of_birth_self', 'citizenship', 'own_business_or_self_employed', "fill_inc_questionnaire_for_veteran's_admin", 'veterans_benefits', 'weeks_worked_in_year', 'year']

# %%
columns.remove('|_instance_weight')
columns.append('incomeBracket')

# %%
try:
    assert(len(columns) == len(us_census_train.columns) == len(us_census_test.columns))
    us_census_train.columns = columns
    us_census_test.columns = columns
except:
    print('Number of column names does not match number of columns in either training or test DataFrames')

# %%
us_census_train.head(50)
# Out:
#     age                 class_of_worker  detailed_industry_recode  \
# 0    73                             NaN                         0
# 1    58  Self-employed-not incorporated                         4
# 2    18                             NaN                         0
# 3     9                             NaN                         0
# 4    10                             NaN                         0
# 5    48                         Private                        40
# 6    42                         Private                        34
# 7    28                         Private                         4
# 8    47                Local government                        43
# 9    34                         Private                         4
# 10    8                             NaN                         0
# 11   32                             NaN                         0
# 12   51                         Private                         4
# 13   46                         Private                        37
# 14   26                         Private                        24
# 15   13                             NaN                         0
# 16   47                         Private                        39
# 17   39                             NaN                         0
# 18   16                             NaN                         0
# 19   35                         Private                        12
# 20   12                             NaN                         0
# 21   27  Self-employed-not incorporated                         4
# 22   56                         Private                        35
# 23   46                         Private                        45
# 24   55                             NaN                         0
# 25    2                             NaN                         0
# 26    1                             NaN                         0
# 27   37                         Private                         3
# 28    4                             NaN                         0
# 29   37                         Private                         4
# 30   63                         Private                        19
# 31   34              Federal government                        29
# 32   46  Self-employed-not incorporated                         4
# 33   25                         Private                        45
# 34   81                             NaN                         0
# 35   46                         Private                        32
# 36   39                         Private                        34
# 37   42              Federal government                        48
# 38    2                             NaN                         0
# 39   11                             NaN                         0
# 40   30                             NaN                         0
# 41    7                             NaN                         0
# 42   66  Self-employed-not incorporated                        33
# 43   26                             NaN                         0
# 44   84                             NaN                         0
# 45   32                         Private                        33
# 46   52                             NaN                         0
# 47    5                             NaN                         0
# 48   35                             NaN                         0
# 49   66                         Private                        37
#
#     detailed_occupation_recode                               education  \
# 0                            0                    High school graduate
# 1                           34              Some college but no degree
# 2                            0                              10th grade
# 3                            0                                Children
# 4                            0                                Children
# 5                           10              Some college but no degree
# 6                            3              Bachelors degree(BA AB BS)
# 7                           40                    High school graduate
# 8                           26              Some college but no degree
# 9                           37              Some college but no degree
# 10                           0                                Children
# 11                           0                    High school graduate
# 12                          34              Some college but no degree
# 13                          31                    High school graduate
# 14                          12              Bachelors degree(BA AB BS)
# 15                           0                                Children
# 16                          36              Bachelors degree(BA AB BS)
# 17                           0                              10th grade
# 18                           0                              10th grade
# 19                          41                    High school graduate
# 20                           0                                Children
# 21                          34              Some college but no degree
# 22                          22              Some college but no degree
# 23                          12  Masters degree(MA MS MEng MEd MSW MBA)
# 24                           0              Some college but no degree
# 25                           0                                Children
# 26                           0                                Children
# 27                          34              Some college but no degree
# 28                           0                                Children
# 29                           2              Bachelors degree(BA AB BS)
# 30                          35                     Less than 1st grade
# 31                          25              Some college but no degree
# 32                          34              Some college but no degree
# 33                          23                    High school graduate
# 34                           0              Bachelors degree(BA AB BS)
# 35                          42                    High school graduate
# 36                           2              Bachelors degree(BA AB BS)
# 37                           8      Associates degree-academic program
# 38                           0                                Children
# 39                           0                                Children
# 40                           0                    High school graduate
# 41                           0                                Children
# 42                          19                       7th and 8th grade
# 43                           0                    High school graduate
# 44                           0                    High school graduate
# 45                          29                    High school graduate
# 46                           0                    High school graduate
# 47                           0                                Children
# 48                           0                    High school graduate
# 49                          36              Some college but no degree
#
#     wage_per_hour enroll_in_edu_inst_last_wk                     marital_stat  \
# 0               0                        NaN                          Widowed
# 1               0                        NaN                         Divorced
# 2               0                High school                    Never married
# 3               0                        NaN                    Never married
# 4               0                        NaN                    Never married
# 5            1200                        NaN  Married-civilian spouse present
# 6               0                        NaN  Married-civilian spouse present
# 7               0                        NaN                    Never married
# 8             876                        NaN  Married-civilian spouse present
# 9               0                        NaN  Married-civilian spouse present
# 10              0                        NaN                    Never married
# 11              0                        NaN                    Never married
# 12              0                        NaN  Married-civilian spouse present
# 13              0                        NaN                         Divorced
# 14              0                        NaN                    Never married
# 15              0                        NaN                    Never married
# 16              0                        NaN                    Never married
# 17              0                        NaN  Married-civilian spouse present
# 18              0                High school                    Never married
# 19              0                        NaN  Married-civilian spouse present
# 20              0                        NaN                    Never married
# 21              0                        NaN  Married-civilian spouse present
# 22            500                        NaN  Married-civilian spouse present
# 23              0                        NaN  Married-civilian spouse present
# 24              0                        NaN  Married-civilian spouse present
# 25              0                        NaN                    Never married
# 26              0                        NaN                    Never married
# 27              0                        NaN  Married-civilian spouse present
# 28              0                        NaN                    Never married
# 29              0                        NaN                    Never married
# 30              0                        NaN  Married-civilian spouse present
# 31              0                        NaN  Married-civilian spouse present
# 32              0                        NaN  Married-civilian spouse present
# 33              0                        NaN                    Never married
# 34              0                        NaN                          Widowed
# 35              0                        NaN                        Separated
# 36              0                        NaN  Married-civilian spouse present
# 37              0                        NaN  Married-civilian spouse present
# 38              0                        NaN                    Never married
# 39              0                        NaN                    Never married
# 40              0                        NaN                    Never married
# 41              0                        NaN                    Never married
# 42              0                        NaN  Married-civilian spouse present
# 43              0                        NaN  Married-civilian spouse present
# 44              0                        NaN  Married-civilian spouse present
# 45              0                        NaN                    Never married
# 46              0                        NaN  Married-civilian spouse present
# 47              0                        NaN                    Never married
# 48              0                        NaN  Married-civilian spouse present
# 49            400                        NaN  Married-civilian spouse present
#
#                     major_industry_code  \
# 0           Not in universe or children
# 1                          Construction
# 2           Not in universe or children
# 3           Not in universe or children
# 4           Not in universe or children
# 5                         Entertainment
# 6     Finance insurance and real estate
# 7                          Construction
# 8                             Education
# 9                          Construction
# 10          Not in universe or children
# 11          Not in universe or children
# 12                         Construction
# 13         Business and repair services
# 14       Manufacturing-nondurable goods
# 15          Not in universe or children
# 16  Personal services except private HH
# 17          Not in universe or children
# 18          Not in universe or children
# 19          Manufacturing-durable goods
# 20          Not in universe or children
# 21                         Construction
# 22    Finance insurance and real estate
# 23          Other professional services
# 24          Not in universe or children
# 25          Not in universe or children
# 26          Not in universe or children
# 27                               Mining
# 28          Not in universe or children
# 29                         Construction
# 30       Manufacturing-nondurable goods
# 31                       Transportation
# 32                         Construction
# 33          Other professional services
# 34          Not in universe or children
# 35                      Wholesale trade
# 36    Finance insurance and real estate
# 37                Public administration
# 38          Not in universe or children
# 39          Not in universe or children
# 40          Not in universe or children
# 41          Not in universe or children
# 42                         Retail trade
# 43          Not in universe or children
# 44          Not in universe or children
# 45                         Retail trade
# 46          Not in universe or children
# 47          Not in universe or children
# 48          Not in universe or children
# 49         Business and repair services
#
#                     major_occupation_code                         race  \
# 0                                     NaN                        White
# 1     Precision production craft & repair                        White
# 2                                     NaN    Asian or Pacific Islander
# 3                                     NaN                        White
# 4                                     NaN                        White
# 5                  Professional specialty  Amer Indian Aleut or Eskimo
# 6          Executive admin and managerial                        White
# 7            Handlers equip cleaners etc                         White
# 8          Adm support including clerical                        White
# 9   Machine operators assmblrs & inspctrs                        White
# 10                                    NaN                        White
# 11                                    NaN                        Black
# 12    Precision production craft & repair                        White
# 13                          Other service                        White
# 14                 Professional specialty                        White
# 15                                    NaN                        Black
# 16  Machine operators assmblrs & inspctrs                        White
# 17                                    NaN                        White
# 18                                    NaN                        White
# 19           Handlers equip cleaners etc                         White
# 20                                    NaN                        Other
# 21    Precision production craft & repair                        White
# 22         Adm support including clerical                        White
# 23                 Professional specialty                        White
# 24                                    NaN    Asian or Pacific Islander
# 25                                    NaN                        White
# 26                                    NaN                        Other
# 27    Precision production craft & repair                        White
# 28                                    NaN                        White
# 29         Executive admin and managerial                        White
# 30    Precision production craft & repair                        Other
# 31         Adm support including clerical                        White
# 32    Precision production craft & repair                        White
# 33         Adm support including clerical                        White
# 34                                    NaN                        White
# 35           Handlers equip cleaners etc                         White
# 36         Executive admin and managerial                        White
# 37                 Professional specialty                        White
# 38                                    NaN                        Black
# 39                                    NaN                        White
# 40                                    NaN                        Black
# 41                                    NaN                        White
# 42                                  Sales                        White
# 43                                    NaN                        White
# 44                                    NaN                        White
# 45                          Other service                        White
# 46                                    NaN                        White
# 47                                    NaN                        White
# 48                                    NaN                        White
# 49  Machine operators assmblrs & inspctrs                        White
#
#               hispanic_origin     sex member_of_a_labor_union  \
# 0                   All other  Female                     NaN
# 1                   All other    Male                     NaN
# 2                   All other  Female                     NaN
# 3                   All other  Female                     NaN
# 4                   All other  Female                     NaN
# 5                   All other  Female                      No
# 6                   All other    Male                     NaN
# 7                   All other  Female                     NaN
# 8                   All other  Female                      No
# 9                   All other    Male                     NaN
# 10                  All other  Female                     NaN
# 11                  All other  Female                     NaN
# 12                Do not know    Male                     NaN
# 13  Central or South American  Female                     NaN
# 14                  All other  Female                     NaN
# 15                  All other  Female                     NaN
# 16                  All other  Female                     NaN
# 17         Mexican (Mexicano)  Female                     NaN
# 18           Mexican-American  Female                     NaN
# 19                  All other    Male                     NaN
# 20           Mexican-American    Male                     NaN
# 21                  All other    Male                     NaN
# 22                  All other  Female                      No
# 23                  All other    Male                     NaN
# 24                  All other  Female                     NaN
# 25                  All other    Male                     NaN
# 26  Central or South American  Female                     NaN
# 27                  All other    Male                     NaN
# 28                  All other  Female                     NaN
# 29                  All other    Male                     NaN
# 30         Mexican (Mexicano)    Male                     NaN
# 31                  All other  Female                     NaN
# 32                  All other    Male                     NaN
# 33                  All other  Female                     NaN
# 34                  All other  Female                     NaN
# 35  Central or South American  Female                     NaN
# 36                  All other    Male                     NaN
# 37                  All other    Male                     NaN
# 38                  All other    Male                     NaN
# 39           Mexican-American  Female                     NaN
# 40                  All other  Female                     NaN
# 41              Other Spanish    Male                     NaN
# 42                  All other  Female                     NaN
# 43           Mexican-American  Female                     NaN
# 44                  All other  Female                     NaN
# 45                  All other  Female                     NaN
# 46                  All other  Female                     NaN
# 47                  All other  Female                     NaN
# 48                  All other  Female                     NaN
# 49                  All other    Male                      No
#
#    reason_for_unemployment   full_or_part_time_employment_stat  capital_gains  \
# 0                      NaN                  Not in labor force              0
# 1                      NaN            Children or Armed Forces              0
# 2                      NaN                  Not in labor force              0
# 3                      NaN            Children or Armed Forces              0
# 4                      NaN            Children or Armed Forces              0
# 5                      NaN                 Full-time schedules              0
# 6                      NaN            Children or Armed Forces           5178
# 7    Job loser - on layoff                Unemployed full-time              0
# 8                      NaN                 Full-time schedules              0
# 9                      NaN            Children or Armed Forces              0
# 10                     NaN            Children or Armed Forces              0
# 11                     NaN                  Not in labor force              0
# 12                     NaN            Children or Armed Forces              0
# 13                     NaN            Children or Armed Forces              0
# 14                     NaN                 Full-time schedules              0
# 15                     NaN            Children or Armed Forces              0
# 16                     NaN                 Full-time schedules              0
# 17                     NaN            Children or Armed Forces              0
# 18                     NaN                  Not in labor force              0
# 19                     NaN                 Full-time schedules              0
# 20                     NaN            Children or Armed Forces              0
# 21                     NaN            Children or Armed Forces              0
# 22                     NaN                 Full-time schedules              0
# 23                     NaN            Children or Armed Forces              0
# 24                     NaN            Children or Armed Forces              0
# 25                     NaN            Children or Armed Forces              0
# 26                     NaN            Children or Armed Forces              0
# 27                     NaN                 Full-time schedules              0
# 28                     NaN            Children or Armed Forces              0
# 29                     NaN            Children or Armed Forces              0
# 30   Job loser - on layoff                Unemployed full-time              0
# 31                     NaN               Unemployed part- time              0
# 32                     NaN            Children or Armed Forces              0
# 33                     NaN            Children or Armed Forces              0
# 34                     NaN            Children or Armed Forces            991
# 35                     NaN            Children or Armed Forces              0
# 36                     NaN            Children or Armed Forces              0
# 37                     NaN  PT for non-econ reasons usually FT              0
# 38                     NaN            Children or Armed Forces              0
# 39                     NaN            Children or Armed Forces              0
# 40                     NaN            Children or Armed Forces              0
# 41                     NaN            Children or Armed Forces              0
# 42                     NaN            Children or Armed Forces              0
# 43                     NaN            Children or Armed Forces              0
# 44                     NaN                  Not in labor force              0
# 45                     NaN                 Full-time schedules              0
# 46                     NaN            Children or Armed Forces              0
# 47                     NaN            Children or Armed Forces              0
# 48                     NaN            Children or Armed Forces              0
# 49                     NaN                 Full-time schedules              0
#
#     capital_losses  dividends_from_stocks       tax_filer_stat  \
# 0                0                      0             Nonfiler
# 1                0                      0    Head of household
# 2                0                      0             Nonfiler
# 3                0                      0             Nonfiler
# 4                0                      0             Nonfiler
# 5                0                      0  Joint both under 65
# 6                0                      0  Joint both under 65
# 7                0                      0               Single
# 8                0                      0  Joint both under 65
# 9                0                      0  Joint both under 65
# 10               0                      0             Nonfiler
# 11               0                      0             Nonfiler
# 12               0                      0  Joint both under 65
# 13            1590                      0               Single
# 14               0                      0               Single
# 15               0                      0             Nonfiler
# 16               0                      0               Single
# 17               0                      0  Joint both under 65
# 18               0                      0             Nonfiler
# 19               0                   6000  Joint both under 65
# 20               0                      0             Nonfiler
# 21               0                      0  Joint both under 65
# 22               0                      0  Joint both under 65
# 23            1977                    100  Joint both under 65
# 24               0                      0  Joint both under 65
# 25               0                      0             Nonfiler
# 26               0                      0             Nonfiler
# 27               0                      0  Joint both under 65
# 28               0                      0             Nonfiler
# 29            1669                    700               Single
# 30               0                      0  Joint both under 65
# 31               0                      0  Joint both under 65
# 32               0                      0  Joint both under 65
# 33               0                      0               Single
# 34               0                      0               Single
# 35               0                      0               Single
# 36               0                   1000  Joint both under 65
# 37               0                     49  Joint both under 65
# 38               0                      0             Nonfiler
# 39               0                      0             Nonfiler
# 40               0                      0             Nonfiler
# 41               0                      0             Nonfiler
# 42               0                      0       Joint both 65+
# 43               0                      0  Joint both under 65
# 44               0                      0       Joint both 65+
# 45               0                     59    Head of household
# 46               0                      0  Joint both under 65
# 47               0                      0             Nonfiler
# 48               0                      0  Joint both under 65
# 49               0                      0       Joint both 65+
#
#    region_of_previous_residence state_of_previous_residence  \
# 0                           NaN                         NaN
# 1                         South                    Arkansas
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# 5                           NaN                         NaN
# 6                           NaN                         NaN
# 7                           NaN                         NaN
# 8                           NaN                         NaN
# 9                           NaN                         NaN
# 10                          NaN                         NaN
# 11                          NaN                         NaN
# 12                          NaN                         NaN
# 13                          NaN                         NaN
# 14                          NaN                         NaN
# 15                          NaN                         NaN
# 16                          NaN                         NaN
# 17                          NaN                         NaN
# 18                          NaN                         NaN
# 19                          NaN                         NaN
# 20                        South                        Utah
# 21                          NaN                         NaN
# 22                          NaN                         NaN
# 23                          NaN                         NaN
# 24                          NaN                         NaN
# 25                          NaN                         NaN
# 26                    Northeast                    Michigan
# 27                          NaN                         NaN
# 28                          NaN                         NaN
# 29                          NaN                         NaN
# 30                          NaN                         NaN
# 31                          NaN                         NaN
# 32                          NaN                         NaN
# 33                          NaN                         NaN
# 34                          NaN                         NaN
# 35                          NaN                         NaN
# 36                          NaN                         NaN
# 37                          NaN                         NaN
# 38                          NaN                         NaN
# 39                          NaN                         NaN
# 40                      Midwest                   Minnesota
# 41                          NaN                         NaN
# 42                          NaN                         NaN
# 43                          NaN                         NaN
# 44                          NaN                         NaN
# 45                          NaN                         NaN
# 46                          NaN                         NaN
# 47                         West                      Alaska
# 48                          NaN                         NaN
# 49                          NaN                         NaN
#
#             detailed_household_and_family_stat  \
# 0     Other Rel 18+ ever marr not in subfamily
# 1                                  Householder
# 2      Child 18+ never marr Not in a subfamily
# 3        Child <18 never marr not in subfamily
# 4        Child <18 never marr not in subfamily
# 5                        Spouse of householder
# 6                                  Householder
# 7                         Secondary individual
# 8                        Spouse of householder
# 9                                  Householder
# 10       Child <18 never marr not in subfamily
# 11   Other Rel 18+ never marr not in subfamily
# 12                                 Householder
# 13                                 Householder
# 14                       Nonfamily householder
# 15       Child <18 never marr not in subfamily
# 16                       Nonfamily householder
# 17                       Spouse of householder
# 18       Child <18 never marr not in subfamily
# 19                                 Householder
# 20       Child <18 never marr not in subfamily
# 21                                 Householder
# 22                       Spouse of householder
# 23                                 Householder
# 24                                 Householder
# 25       Child <18 never marr not in subfamily
# 26       Child <18 never marr not in subfamily
# 27                       Spouse of householder
# 28       Child <18 never marr not in subfamily
# 29                        Secondary individual
# 30                                 Householder
# 31                       Spouse of householder
# 32                                 Householder
# 33     Child 18+ never marr Not in a subfamily
# 34                       Nonfamily householder
# 35                                 Householder
# 36                                 Householder
# 37                                 Householder
# 38  Grandchild <18 never marr not in subfamily
# 39       Child <18 never marr not in subfamily
# 40                                 Householder
# 41       Child <18 never marr not in subfamily
# 42                       Spouse of householder
# 43                       Spouse of householder
# 44                       Spouse of householder
# 45                                 Householder
# 46                       Spouse of householder
# 47       Child <18 never marr not in subfamily
# 48                       Spouse of householder
# 49                                 Householder
#
#    detailed_household_summary_in_household  instance_weight  \
# 0            Other relative of householder          1700.09
# 1                              Householder          1053.55
# 2                        Child 18 or older           991.95
# 3             Child under 18 never married          1758.14
# 4             Child under 18 never married          1069.16
# 5                    Spouse of householder           162.61
# 6                              Householder          1535.86
# 7               Nonrelative of householder           898.83
# 8                    Spouse of householder          1661.53
# 9                              Householder          1146.79
# 10            Child under 18 never married          2466.24
# 11           Other relative of householder          2021.27
# 12                             Householder          2441.22
# 13                             Householder           978.16
# 14                             Householder          2604.91
# 15            Child under 18 never married          1520.08
# 16                             Householder           404.90
# 17                   Spouse of householder          1274.04
# 18            Child under 18 never married          1555.29
# 19                             Householder          1790.75
# 20            Child under 18 never married           455.02
# 21                             Householder          1004.69
# 22                   Spouse of householder          1500.08
# 23                             Householder           999.46
# 24                             Householder          1483.69
# 25            Child under 18 never married          1660.53
# 26            Child under 18 never married           848.25
# 27                   Spouse of householder          2671.99
# 28            Child under 18 never married          1188.42
# 29              Nonrelative of householder          1331.35
# 30                             Householder           711.15
# 31                   Spouse of householder          1578.65
# 32                             Householder          1629.02
# 33                       Child 18 or older          1998.03
# 34                             Householder           463.55
# 35                             Householder          2492.74
# 36                             Householder           980.10
# 37                             Householder          1539.40
# 38           Other relative of householder          2621.94
# 39            Child under 18 never married           498.25
# 40                             Householder          1773.08
# 41            Child under 18 never married           885.84
# 42                   Spouse of householder          4183.26
# 43                   Spouse of householder          1040.15
# 44                   Spouse of householder          3494.72
# 45                             Householder          1130.25
# 46                   Spouse of householder          1407.39
# 47            Child under 18 never married           235.92
# 48                   Spouse of householder          1669.47
# 49                             Householder          1212.48
#
#    migration_code-change_in_msa migration_code-change_in_reg  \
# 0                             ?                            ?
# 1                    MSA to MSA                  Same county
# 2                             ?                            ?
# 3                      Nonmover                     Nonmover
# 4                      Nonmover                     Nonmover
# 5                             ?                            ?
# 6                      Nonmover                     Nonmover
# 7                             ?                            ?
# 8                             ?                            ?
# 9                      Nonmover                     Nonmover
# 10                     Nonmover                     Nonmover
# 11                            ?                            ?
# 12                     Nonmover                     Nonmover
# 13                     Nonmover                     Nonmover
# 14                            ?                            ?
# 15                     Nonmover                     Nonmover
# 16                            ?                            ?
# 17                     Nonmover                     Nonmover
# 18                            ?                            ?
# 19                            ?                            ?
# 20                   MSA to MSA             Different region
# 21                     Nonmover                     Nonmover
# 22                            ?                            ?
# 23                     Nonmover                     Nonmover
# 24                     Nonmover                     Nonmover
# 25                     Nonmover                     Nonmover
# 26                   MSA to MSA  Different county same state
# 27                            ?                            ?
# 28                            ?                            ?
# 29                     Nonmover                     Nonmover
# 30                            ?                            ?
# 31                            ?                            ?
# 32                     Nonmover                     Nonmover
# 33                     Nonmover                     Nonmover
# 34                     Nonmover                     Nonmover
# 35                     Nonmover                     Nonmover
# 36                     Nonmover                     Nonmover
# 37                            ?                            ?
# 38                            ?                            ?
# 39                     Nonmover                     Nonmover
# 40                   MSA to MSA                  Same county
# 41                     Nonmover                     Nonmover
# 42                     Nonmover                     Nonmover
# 43                     Nonmover                     Nonmover
# 44                            ?                            ?
# 45                            ?                            ?
# 46                     Nonmover                     Nonmover
# 47                   MSA to MSA                  Same county
# 48                     Nonmover                     Nonmover
# 49                            ?                            ?
#
#    migration_code-move_within_reg     live_in_this_house_1_year_ago  \
# 0                               ?  Not in universe under 1 year old
# 1                     Same county                                No
# 2                               ?  Not in universe under 1 year old
# 3                        Nonmover                               Yes
# 4                        Nonmover                               Yes
# 5                               ?  Not in universe under 1 year old
# 6                        Nonmover                               Yes
# 7                               ?  Not in universe under 1 year old
# 8                               ?  Not in universe under 1 year old
# 9                        Nonmover                               Yes
# 10                       Nonmover                               Yes
# 11                              ?  Not in universe under 1 year old
# 12                       Nonmover                               Yes
# 13                       Nonmover                               Yes
# 14                              ?  Not in universe under 1 year old
# 15                       Nonmover                               Yes
# 16                              ?  Not in universe under 1 year old
# 17                       Nonmover                               Yes
# 18                              ?  Not in universe under 1 year old
# 19                              ?  Not in universe under 1 year old
# 20       Different state in South                                No
# 21                       Nonmover                               Yes
# 22                              ?  Not in universe under 1 year old
# 23                       Nonmover                               Yes
# 24                       Nonmover                               Yes
# 25                       Nonmover                               Yes
# 26    Different county same state                                No
# 27                              ?  Not in universe under 1 year old
# 28                              ?  Not in universe under 1 year old
# 29                       Nonmover                               Yes
# 30                              ?  Not in universe under 1 year old
# 31                              ?  Not in universe under 1 year old
# 32                       Nonmover                               Yes
# 33                       Nonmover                               Yes
# 34                       Nonmover                               Yes
# 35                       Nonmover                               Yes
# 36                       Nonmover                               Yes
# 37                              ?  Not in universe under 1 year old
# 38                              ?  Not in universe under 1 year old
# 39                       Nonmover                               Yes
# 40                    Same county                                No
# 41                       Nonmover                               Yes
# 42                       Nonmover                               Yes
# 43                       Nonmover                               Yes
# 44                              ?  Not in universe under 1 year old
# 45                              ?  Not in universe under 1 year old
# 46                       Nonmover                               Yes
# 47                    Same county                                No
# 48                       Nonmover                               Yes
# 49                              ?  Not in universe under 1 year old
#
#    migration_prev_res_in_sunbelt  num_persons_worked_for_employer  \
# 0                              ?                                0
# 1                            Yes                                1
# 2                              ?                                0
# 3                            NaN                                0
# 4                            NaN                                0
# 5                              ?                                1
# 6                            NaN                                6
# 7                              ?                                4
# 8                              ?                                5
# 9                            NaN                                6
# 10                           NaN                                0
# 11                             ?                                0
# 12                           NaN                                3
# 13                           NaN                                6
# 14                             ?                                6
# 15                           NaN                                0
# 16                             ?                                6
# 17                           NaN                                0
# 18                             ?                                0
# 19                             ?                                4
# 20                           Yes                                0
# 21                           NaN                                6
# 22                             ?                                2
# 23                           NaN                                1
# 24                           NaN                                0
# 25                           NaN                                0
# 26                            No                                0
# 27                             ?                                3
# 28                             ?                                0
# 29                           NaN                                6
# 30                             ?                                6
# 31                             ?                                6
# 32                           NaN                                1
# 33                           NaN                                1
# 34                           NaN                                0
# 35                           NaN                                3
# 36                           NaN                                6
# 37                             ?                                6
# 38                             ?                                0
# 39                           NaN                                0
# 40                            No                                0
# 41                           NaN                                0
# 42                           NaN                                1
# 43                           NaN                                0
# 44                             ?                                0
# 45                             ?                                6
# 46                           NaN                                0
# 47                            No                                0
# 48                           NaN                                0
# 49                             ?                                2
#
#    family_members_under_18 country_of_birth_father country_of_birth_mother  \
# 0                      NaN           United-States           United-States
# 1                      NaN           United-States           United-States
# 2                      NaN                 Vietnam                 Vietnam
# 3     Both parents present           United-States           United-States
# 4     Both parents present           United-States           United-States
# 5                      NaN             Philippines           United-States
# 6                      NaN           United-States           United-States
# 7                      NaN           United-States           United-States
# 8                      NaN           United-States           United-States
# 9                      NaN           United-States           United-States
# 10    Both parents present           United-States           United-States
# 11                     NaN                       ?                       ?
# 12                     NaN           United-States           United-States
# 13                     NaN                Columbia                Columbia
# 14                     NaN           United-States           United-States
# 15    Both parents present           United-States           United-States
# 16                     NaN                 Germany           United-States
# 17                     NaN                  Mexico                  Mexico
# 18    Both parents present           United-States             El-Salvador
# 19                     NaN           United-States           United-States
# 20    Both parents present           United-States           United-States
# 21                     NaN           United-States           United-States
# 22                     NaN           United-States           United-States
# 23                     NaN           United-States           United-States
# 24                     NaN                   Japan           United-States
# 25    Both parents present           United-States           United-States
# 26     Mother only present                       ?                       ?
# 27                     NaN           United-States           United-States
# 28    Both parents present           United-States           United-States
# 29                     NaN           United-States           United-States
# 30                     NaN                  Mexico                  Mexico
# 31                     NaN           United-States           United-States
# 32                     NaN           United-States           United-States
# 33                     NaN           United-States           United-States
# 34                     NaN                       ?           United-States
# 35                     NaN                    Peru                    Peru
# 36                     NaN           United-States           United-States
# 37                     NaN           United-States           United-States
# 38  Neither parent present           United-States           United-States
# 39     Mother only present                  Mexico                  Mexico
# 40                     NaN           United-States           United-States
# 41    Both parents present      Dominican-Republic             Puerto-Rico
# 42                     NaN           United-States           United-States
# 43                     NaN                  Mexico                  Mexico
# 44                     NaN           United-States           United-States
# 45                     NaN           United-States           United-States
# 46                     NaN           United-States           United-States
# 47     Mother only present           United-States           United-States
# 48                     NaN           United-States           United-States
# 49                     NaN           United-States           United-States
#
#    country_of_birth_self                          citizenship  \
# 0          United-States    Native- Born in the United States
# 1          United-States    Native- Born in the United States
# 2                Vietnam  Foreign born- Not a citizen of U S
# 3          United-States    Native- Born in the United States
# 4          United-States    Native- Born in the United States
# 5          United-States    Native- Born in the United States
# 6          United-States    Native- Born in the United States
# 7          United-States    Native- Born in the United States
# 8          United-States    Native- Born in the United States
# 9          United-States    Native- Born in the United States
# 10         United-States    Native- Born in the United States
# 11                     ?  Foreign born- Not a citizen of U S
# 12         United-States    Native- Born in the United States
# 13              Columbia  Foreign born- Not a citizen of U S
# 14         United-States    Native- Born in the United States
# 15         United-States    Native- Born in the United States
# 16         United-States    Native- Born in the United States
# 17                Mexico  Foreign born- Not a citizen of U S
# 18         United-States    Native- Born in the United States
# 19         United-States    Native- Born in the United States
# 20         United-States    Native- Born in the United States
# 21         United-States    Native- Born in the United States
# 22         United-States    Native- Born in the United States
# 23         United-States    Native- Born in the United States
# 24         United-States    Native- Born in the United States
# 25         United-States    Native- Born in the United States
# 26         United-States    Native- Born in the United States
# 27         United-States    Native- Born in the United States
# 28         United-States    Native- Born in the United States
# 29         United-States    Native- Born in the United States
# 30                Mexico  Foreign born- Not a citizen of U S
# 31         United-States    Native- Born in the United States
# 32         United-States    Native- Born in the United States
# 33         United-States    Native- Born in the United States
# 34         United-States    Native- Born in the United States
# 35                  Peru  Foreign born- Not a citizen of U S
# 36         United-States    Native- Born in the United States
# 37         United-States    Native- Born in the United States
# 38         United-States    Native- Born in the United States
# 39         United-States    Native- Born in the United States
# 40         United-States    Native- Born in the United States
# 41         United-States    Native- Born in the United States
# 42         United-States    Native- Born in the United States
# 43                Mexico  Foreign born- Not a citizen of U S
# 44         United-States    Native- Born in the United States
# 45         United-States    Native- Born in the United States
# 46         United-States    Native- Born in the United States
# 47         United-States    Native- Born in the United States
# 48         United-States    Native- Born in the United States
# 49         United-States    Native- Born in the United States
#
#     own_business_or_self_employed fill_inc_questionnaire_for_veteran's_admin  \
# 0                               0                                        NaN
# 1                               0                                        NaN
# 2                               0                                        NaN
# 3                               0                                        NaN
# 4                               0                                        NaN
# 5                               2                                        NaN
# 6                               0                                        NaN
# 7                               0                                        NaN
# 8                               0                                        NaN
# 9                               0                                        NaN
# 10                              0                                        NaN
# 11                              0                                        NaN
# 12                              0                                        NaN
# 13                              0                                        NaN
# 14                              0                                        NaN
# 15                              0                                        NaN
# 16                              0                                        NaN
# 17                              0                                        NaN
# 18                              0                                        NaN
# 19                              0                                        NaN
# 20                              0                                        NaN
# 21                              1                                        NaN
# 22                              2                                        NaN
# 23                              0                                        NaN
# 24                              0                                        NaN
# 25                              0                                        NaN
# 26                              0                                        NaN
# 27                              0                                        NaN
# 28                              0                                        NaN
# 29                              0                                        NaN
# 30                              0                                        NaN
# 31                              0                                        NaN
# 32                              0                                        NaN
# 33                              0                                        NaN
# 34                              0                                        NaN
# 35                              0                                        NaN
# 36                              0                                        NaN
# 37                              0                                        NaN
# 38                              0                                        NaN
# 39                              0                                        NaN
# 40                              0                                        NaN
# 41                              0                                        NaN
# 42                              0                                        NaN
# 43                              0                                        NaN
# 44                              0                                        NaN
# 45                              0                                        NaN
# 46                              0                                        NaN
# 47                              0                                        NaN
# 48                              0                                        NaN
# 49                              0                                        NaN
#
#     veterans_benefits  weeks_worked_in_year  year incomeBracket
# 0                   2                     0    95      - 50000.
# 1                   2                    52    94      - 50000.
# 2                   2                     0    95      - 50000.
# 3                   0                     0    94      - 50000.
# 4                   0                     0    94      - 50000.
# 5                   2                    52    95      - 50000.
# 6                   2                    52    94      - 50000.
# 7                   2                    30    95      - 50000.
# 8                   2                    52    95      - 50000.
# 9                   2                    52    94      - 50000.
# 10                  0                     0    94      - 50000.
# 11                  2                     0    95      - 50000.
# 12                  2                    52    94      - 50000.
# 13                  2                    52    94      - 50000.
# 14                  2                    52    95      - 50000.
# 15                  0                     0    94      - 50000.
# 16                  2                    52    95      - 50000.
# 17                  2                     0    94      - 50000.
# 18                  2                     0    95      - 50000.
# 19                  2                    49    95      - 50000.
# 20                  0                     0    94      - 50000.
# 21                  2                    52    94      - 50000.
# 22                  2                    32    95      - 50000.
# 23                  2                    52    94      - 50000.
# 24                  2                     0    94      - 50000.
# 25                  0                     0    94      - 50000.
# 26                  0                     0    94      - 50000.
# 27                  2                    52    95      - 50000.
# 28                  0                     0    95      - 50000.
# 29                  2                    52    94      - 50000.
# 30                  2                    15    95      - 50000.
# 31                  2                    52    95      - 50000.
# 32                  2                    52    94      - 50000.
# 33                  2                    52    94      - 50000.
# 34                  2                     0    94      - 50000.
# 35                  2                    52    94      - 50000.
# 36                  2                    52    94      - 50000.
# 37                  2                    52    95      - 50000.
# 38                  0                     0    95      - 50000.
# 39                  0                     0    94      - 50000.
# 40                  2                     0    94      - 50000.
# 41                  0                     0    94      - 50000.
# 42                  2                    38    94      - 50000.
# 43                  2                     0    94      - 50000.
# 44                  2                     0    95      - 50000.
# 45                  2                    52    95      - 50000.
# 46                  2                     0    94      - 50000.
# 47                  0                     0    94      - 50000.
# 48                  2                     0    94      - 50000.
# 49                  2                    52    95      - 50000.

# %% [markdown]
# ## Data Cleaning

# %%
us_census_train['binaryIncome'] = (us_census_train['incomeBracket'] == '50000+.').astype(int)
us_census_train.drop('incomeBracket', axis=1, inplace=True)

us_census_test['binaryIncome'] = (us_census_test['incomeBracket'] == '50000+.').astype(int)
us_census_test.drop('incomeBracket', axis=1, inplace=True)

# %%
us_census_train.describe(include='all')
# Out:
#                   age class_of_worker  detailed_industry_recode  \
# count   199523.000000           99278             199523.000000
# unique            NaN               8                       NaN
# top               NaN         Private                       NaN
# freq              NaN           72028                       NaN
# mean        34.494199             NaN                 15.352320
# std         22.310895             NaN                 18.067129
# min          0.000000             NaN                  0.000000
# 25%         15.000000             NaN                  0.000000
# 50%         33.000000             NaN                  0.000000
# 75%         50.000000             NaN                 33.000000
# max         90.000000             NaN                 51.000000
#
#         detailed_occupation_recode             education  wage_per_hour  \
# count                199523.000000                199523  199523.000000
# unique                         NaN                    17            NaN
# top                            NaN  High school graduate            NaN
# freq                           NaN                 48407            NaN
# mean                     11.306556                   NaN      55.426908
# std                      14.454204                   NaN     274.896454
# min                       0.000000                   NaN       0.000000
# 25%                       0.000000                   NaN       0.000000
# 50%                       0.000000                   NaN       0.000000
# 75%                      26.000000                   NaN       0.000000
# max                      46.000000                   NaN    9999.000000
#
#        enroll_in_edu_inst_last_wk   marital_stat          major_industry_code  \
# count                       12580         199523                       199523
# unique                          2              7                           24
# top                   High school  Never married  Not in universe or children
# freq                         6892          86485                       100684
# mean                          NaN            NaN                          NaN
# std                           NaN            NaN                          NaN
# min                           NaN            NaN                          NaN
# 25%                           NaN            NaN                          NaN
# 50%                           NaN            NaN                          NaN
# 75%                           NaN            NaN                          NaN
# max                           NaN            NaN                          NaN
#
#                  major_occupation_code    race hispanic_origin     sex  \
# count                            98839  199523          198649  199523
# unique                              14       5               9       2
# top     Adm support including clerical   White       All other  Female
# freq                             14837  167365          171907  103984
# mean                               NaN     NaN             NaN     NaN
# std                                NaN     NaN             NaN     NaN
# min                                NaN     NaN             NaN     NaN
# 25%                                NaN     NaN             NaN     NaN
# 50%                                NaN     NaN             NaN     NaN
# 75%                                NaN     NaN             NaN     NaN
# max                                NaN     NaN             NaN     NaN
#
#        member_of_a_labor_union reason_for_unemployment  \
# count                    19064                    6070
# unique                       2                       5
# top                         No         Other job loser
# freq                     16034                    2038
# mean                       NaN                     NaN
# std                        NaN                     NaN
# min                        NaN                     NaN
# 25%                        NaN                     NaN
# 50%                        NaN                     NaN
# 75%                        NaN                     NaN
# max                        NaN                     NaN
#
#        full_or_part_time_employment_stat  capital_gains  capital_losses  \
# count                             199523   199523.00000   199523.000000
# unique                                 8            NaN             NaN
# top             Children or Armed Forces            NaN             NaN
# freq                              123769            NaN             NaN
# mean                                 NaN      434.71899       37.313788
# std                                  NaN     4697.53128      271.896428
# min                                  NaN        0.00000        0.000000
# 25%                                  NaN        0.00000        0.000000
# 50%                                  NaN        0.00000        0.000000
# 75%                                  NaN        0.00000        0.000000
# max                                  NaN    99999.00000     4608.000000
#
#         dividends_from_stocks tax_filer_stat region_of_previous_residence  \
# count           199523.000000         199523                        15773
# unique                    NaN              6                            5
# top                       NaN       Nonfiler                        South
# freq                      NaN          75094                         4889
# mean               197.529533            NaN                          NaN
# std               1984.163658            NaN                          NaN
# min                  0.000000            NaN                          NaN
# 25%                  0.000000            NaN                          NaN
# 50%                  0.000000            NaN                          NaN
# 75%                  0.000000            NaN                          NaN
# max              99999.000000            NaN                          NaN
#
#        state_of_previous_residence detailed_household_and_family_stat  \
# count                        15773                             199523
# unique                          50                                 38
# top                     California                        Householder
# freq                          1714                              53248
# mean                           NaN                                NaN
# std                            NaN                                NaN
# min                            NaN                                NaN
# 25%                            NaN                                NaN
# 50%                            NaN                                NaN
# 75%                            NaN                                NaN
# max                            NaN                                NaN
#
#        detailed_household_summary_in_household  instance_weight  \
# count                                   199523    199523.000000
# unique                                       8              NaN
# top                                Householder              NaN
# freq                                     75475              NaN
# mean                                       NaN      1740.380269
# std                                        NaN       993.768156
# min                                        NaN        37.870000
# 25%                                        NaN      1061.615000
# 50%                                        NaN      1618.310000
# 75%                                        NaN      2188.610000
# max                                        NaN     18656.300000
#
#        migration_code-change_in_msa migration_code-change_in_reg  \
# count                        198007                       198007
# unique                            9                            8
# top                               ?                            ?
# freq                          99696                        99696
# mean                            NaN                          NaN
# std                             NaN                          NaN
# min                             NaN                          NaN
# 25%                             NaN                          NaN
# 50%                             NaN                          NaN
# 75%                             NaN                          NaN
# max                             NaN                          NaN
#
#        migration_code-move_within_reg     live_in_this_house_1_year_ago  \
# count                          198007                            199523
# unique                              9                                 3
# top                                 ?  Not in universe under 1 year old
# freq                            99696                            101212
# mean                              NaN                               NaN
# std                               NaN                               NaN
# min                               NaN                               NaN
# 25%                               NaN                               NaN
# 50%                               NaN                               NaN
# 75%                               NaN                               NaN
# max                               NaN                               NaN
#
#        migration_prev_res_in_sunbelt  num_persons_worked_for_employer  \
# count                         115469                    199523.000000
# unique                             3                              NaN
# top                                ?                              NaN
# freq                           99696                              NaN
# mean                             NaN                         1.956180
# std                              NaN                         2.365126
# min                              NaN                         0.000000
# 25%                              NaN                         0.000000
# 50%                              NaN                         1.000000
# 75%                              NaN                         4.000000
# max                              NaN                         6.000000
#
#        family_members_under_18 country_of_birth_father  \
# count                    55291                  199523
# unique                       4                      43
# top       Both parents present           United-States
# freq                     38983                  159163
# mean                       NaN                     NaN
# std                        NaN                     NaN
# min                        NaN                     NaN
# 25%                        NaN                     NaN
# 50%                        NaN                     NaN
# 75%                        NaN                     NaN
# max                        NaN                     NaN
#
#        country_of_birth_mother country_of_birth_self  \
# count                   199523                199523
# unique                      43                    43
# top              United-States         United-States
# freq                    160479                176989
# mean                       NaN                   NaN
# std                        NaN                   NaN
# min                        NaN                   NaN
# 25%                        NaN                   NaN
# 50%                        NaN                   NaN
# 75%                        NaN                   NaN
# max                        NaN                   NaN
#
#                               citizenship  own_business_or_self_employed  \
# count                              199523                  199523.000000
# unique                                  5                            NaN
# top     Native- Born in the United States                            NaN
# freq                               176992                            NaN
# mean                                  NaN                       0.175438
# std                                   NaN                       0.553694
# min                                   NaN                       0.000000
# 25%                                   NaN                       0.000000
# 50%                                   NaN                       0.000000
# 75%                                   NaN                       0.000000
# max                                   NaN                       2.000000
#
#        fill_inc_questionnaire_for_veteran's_admin  veterans_benefits  \
# count                                        1984      199523.000000
# unique                                          2                NaN
# top                                            No                NaN
# freq                                         1593                NaN
# mean                                          NaN           1.514833
# std                                           NaN           0.851473
# min                                           NaN           0.000000
# 25%                                           NaN           2.000000
# 50%                                           NaN           2.000000
# 75%                                           NaN           2.000000
# max                                           NaN           2.000000
#
#         weeks_worked_in_year           year   binaryIncome
# count          199523.000000  199523.000000  199523.000000
# unique                   NaN            NaN            NaN
# top                      NaN            NaN            NaN
# freq                     NaN            NaN            NaN
# mean               23.174897      94.499672       0.062058
# std                24.411488       0.500001       0.241261
# min                 0.000000      94.000000       0.000000
# 25%                 0.000000      94.000000       0.000000
# 50%                 8.000000      94.000000       0.000000
# 75%                52.000000      95.000000       0.000000
# max                52.000000      95.000000       1.000000

# %%
us_census_train = us_census_train.replace('\?', np.nan, regex=True)
us_census_test = us_census_test.replace('\?', np.nan, regex=True)

# %%
for col in us_census_train.columns:
    nullPercent = (us_census_train[col].isna().sum()/len(us_census_train[col]))*100
    print('{} : {:.2f}% null'.format(col, nullPercent))
# Out:
# age : 0.00% null
# class_of_worker : 50.24% null
# detailed_industry_recode : 0.00% null
# detailed_occupation_recode : 0.00% null
# education : 0.00% null
# wage_per_hour : 0.00% null
# enroll_in_edu_inst_last_wk : 93.69% null
# marital_stat : 0.00% null
# major_industry_code : 0.00% null
# major_occupation_code : 50.46% null
# race : 0.00% null
# hispanic_origin : 0.44% null
# sex : 0.00% null
# member_of_a_labor_union : 90.45% null
# reason_for_unemployment : 96.96% null
# full_or_part_time_employment_stat : 0.00% null
# capital_gains : 0.00% null
# capital_losses : 0.00% null
# dividends_from_stocks : 0.00% null
# tax_filer_stat : 0.00% null
# region_of_previous_residence : 92.09% null
# state_of_previous_residence : 92.45% null
# detailed_household_and_family_stat : 0.00% null
# detailed_household_summary_in_household : 0.00% null
# instance_weight : 0.00% null
# migration_code-change_in_msa : 50.73% null
# migration_code-change_in_reg : 50.73% null
# migration_code-move_within_reg : 50.73% null
# live_in_this_house_1_year_ago : 0.00% null
# migration_prev_res_in_sunbelt : 92.09% null
# num_persons_worked_for_employer : 0.00% null
# family_members_under_18 : 72.29% null
# country_of_birth_father : 3.36% null
# country_of_birth_mother : 3.07% null
# country_of_birth_self : 1.70% null
# citizenship : 0.00% null
# own_business_or_self_employed : 0.00% null
# fill_inc_questionnaire_for_veteran's_admin : 99.01% null
# veterans_benefits : 0.00% null
# weeks_worked_in_year : 0.00% null
# year : 0.00% null
# binaryIncome : 0.00% null

# %%
us_census_train[us_census_train.select_dtypes(['object']).columns] = us_census_train.select_dtypes(['object']).apply(lambda x: x.astype('category'))
us_census_train[['detailed_industry_recode','detailed_occupation_recode','own_business_or_self_employed','veterans_benefits','year']] = us_census_train[['detailed_industry_recode','detailed_occupation_recode','own_business_or_self_employed','veterans_benefits','year']].astype('category')

us_census_test[us_census_test.select_dtypes(['object']).columns] = us_census_test.select_dtypes(['object']).apply(lambda x: x.astype('category'))
us_census_test[['detailed_industry_recode','detailed_occupation_recode','own_business_or_self_employed','veterans_benefits','year']] = us_census_test[['detailed_industry_recode','detailed_occupation_recode','own_business_or_self_employed','veterans_benefits','year']].astype('category')

# %%
us_census_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199523 entries, 0 to 199522
# Data columns (total 42 columns):
# age                                           199523 non-null int64
# class_of_worker                               99278 non-null category
# detailed_industry_recode                      199523 non-null category
# detailed_occupation_recode                    199523 non-null category
# education                                     199523 non-null category
# wage_per_hour                                 199523 non-null int64
# enroll_in_edu_inst_last_wk                    12580 non-null category
# marital_stat                                  199523 non-null category
# major_industry_code                           199523 non-null category
# major_occupation_code                         98839 non-null category
# race                                          199523 non-null category
# hispanic_origin                               198649 non-null category
# sex                                           199523 non-null category
# member_of_a_labor_union                       19064 non-null category
# reason_for_unemployment                       6070 non-null category
# full_or_part_time_employment_stat             199523 non-null category
# capital_gains                                 199523 non-null int64
# capital_losses                                199523 non-null int64
# dividends_from_stocks                         199523 non-null int64
# tax_filer_stat                                199523 non-null category
# region_of_previous_residence                  15773 non-null category
# state_of_previous_residence                   15065 non-null category
# detailed_household_and_family_stat            199523 non-null category
# detailed_household_summary_in_household       199523 non-null category
# instance_weight                               199523 non-null float64
# migration_code-change_in_msa                  98311 non-null category
# migration_code-change_in_reg                  98311 non-null category
# migration_code-move_within_reg                98311 non-null category
# live_in_this_house_1_year_ago                 199523 non-null category
# migration_prev_res_in_sunbelt                 15773 non-null category
# num_persons_worked_for_employer               199523 non-null int64
# family_members_under_18                       55291 non-null category
# country_of_birth_father                       192810 non-null category
# country_of_birth_mother                       193404 non-null category
# country_of_birth_self                         196130 non-null category
# citizenship                                   199523 non-null category
# own_business_or_self_employed                 199523 non-null category
# fill_inc_questionnaire_for_veteran's_admin    1984 non-null category
# veterans_benefits                             199523 non-null category
# weeks_worked_in_year                          199523 non-null int64
# year                                          199523 non-null category
# incomeBracket                                 199523 non-null int64
# dtypes: category(33), float64(1), int64(8)
# memory usage: 20.0 MB

# %% [markdown]
# ## Data Visualisation

# %%
for i, col in enumerate(us_census_train.select_dtypes(['category'])):
    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))
    sns.countplot(x = col, data=us_census_train, ax=ax[0])
    ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=90)
    
    incomeByCol = us_census_train.groupby(col)['binaryIncome'].mean().reset_index()
    sns.barplot(x=col, y='binaryIncome', data=incomeByCol, ax=ax[1])
    ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=90)

# %%
for i, col in enumerate(us_census_train.select_dtypes(['int64'])):
    # Cut the window in 2 parts
    fig, ax = plt.subplots(nrows=2, ncols=1, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})

    # Add a graph in each part
    sns.boxplot(us_census_train[col], ax=ax[0])
    sns.distplot(us_census_train[col], ax=ax[1])

    # Remove x axis name for the boxplot
    ax[0].set(xlabel='')
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Modelling Income

# %%
X_train = pd.DataFrame()
X_test = pd.DataFrame()

for col in learndf:
    try:
        if learndf[col].dtype.name == 'int64' or learndf[col].dtype.name == 'float64' :
            col_train = pd.DataFrame({col : learndf[col]})
            col_test = pd.DataFrame({col : testdf[col]})
        elif learndf[col].dtype.name == 'object':
            col_train = pd.get_dummies(learndf[col], prefix=str(col))
            col_test = pd.get_dummies(testdf[col], prefix=str(col))
        else:
            print('bad type')
            () + 1
        assert isinstance(col_train, pd.DataFrame)
        assert isinstance(col_test, pd.DataFrame)
        if len(col_train.columns) != len(col_test.columns):
            for newcol in col_train:
                if newcol not in col_test.columns:
                    col_test[newcol] = 0
        X_train = pd.concat([X_train, col_train], axis=1)
        X_test = pd.concat([X_test, col_test], axis=1)
    except:
        print("Exception on column {}: {}".format(col, sys.exc_info()[0]))
        raise

X_train.describe(include='all')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-61909d32c33b> in <module>
#       2 X_test = pd.DataFrame()
#       3
# ----> 4 for col in learndf:
#       5     try:
#       6         if learndf[col].dtype.name == 'int64' or learndf[col].dtype.name == 'float64' :
#
# NameError: name 'learndf' is not defined

# %%
X_train = pd.DataFrame()
X_test = pd.DataFrame()

assert sorted(us_census_train.columns) == sorted(us_census_test.columns)

for col in us_census_train:
    try:
        if us_census_train[col].dtype.name == 'int64' or us_census_train[col].dtype.name == 'float64':
            X_train_col = pd.DataFrame(us_census_train[col])
            X_test_col = pd.DataFrame(us_census_test[col])
        elif us_census_train[col].dtype.name == 'category':
            X_train_col = pd.get_dummies(us_census_train[col], prefix=str(col))
            X_test_col = pd.get_dummies(us_census_test[col], prefix=str(col))
        else:
            print('Column {} not of appropriate type'.format(col))
        if sorted(X_train_col.columns) != sorted(X_test_col.columns):
            for newTrainCol in X_train_col:
                if newTrainCol not in X_test_col.columns:
                    X_test_col[newTrainCol] = 0
            for newTestCol in X_test_col:
                if newTestCol not in X_test_col.columns:
                    X_train_col[newTestCol] = 0
        X_train = pd.concat([X_train, X_train_col], axis=1)
        X_test = pd.concat([X_test, X_test_col], axis=1)
    except:
        print("Exception on column {}".format(col))

X_train.describe(include='all')
# Out:
#                  age  class_of_worker_Federal government  \
# count  199523.000000                       199523.000000
# mean       34.494199                            0.014660
# std        22.310895                            0.120188
# min         0.000000                            0.000000
# 25%        15.000000                            0.000000
# 50%        33.000000                            0.000000
# 75%        50.000000                            0.000000
# max        90.000000                            1.000000
#
#        class_of_worker_Local government  class_of_worker_Never worked  \
# count                     199523.000000                 199523.000000
# mean                           0.039013                      0.002200
# std                            0.193626                      0.046855
# min                            0.000000                      0.000000
# 25%                            0.000000                      0.000000
# 50%                            0.000000                      0.000000
# 75%                            0.000000                      0.000000
# max                            1.000000                      1.000000
#
#        class_of_worker_Private  class_of_worker_Self-employed-incorporated  \
# count            199523.000000                               199523.000000
# mean                  0.361001                                    0.016364
# std                   0.480292                                    0.126871
# min                   0.000000                                    0.000000
# 25%                   0.000000                                    0.000000
# 50%                   0.000000                                    0.000000
# 75%                   1.000000                                    0.000000
# max                   1.000000                                    1.000000
#
#        class_of_worker_Self-employed-not incorporated  \
# count                                   199523.000000
# mean                                         0.042326
# std                                          0.201332
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                          1.000000
#
#        class_of_worker_State government  class_of_worker_Without pay  \
# count                     199523.000000                199523.000000
# mean                           0.021186                     0.000827
# std                            0.144003                     0.028745
# min                            0.000000                     0.000000
# 25%                            0.000000                     0.000000
# 50%                            0.000000                     0.000000
# 75%                            0.000000                     0.000000
# max                            1.000000                     1.000000
#
#        detailed_industry_recode_0  detailed_industry_recode_1  \
# count               199523.000000               199523.000000
# mean                     0.504624                    0.004145
# std                      0.499980                    0.064247
# min                      0.000000                    0.000000
# 25%                      0.000000                    0.000000
# 50%                      1.000000                    0.000000
# 75%                      1.000000                    0.000000
# max                      1.000000                    1.000000
#
#        detailed_industry_recode_2  detailed_industry_recode_3  \
# count               199523.000000               199523.000000
# mean                     0.011006                    0.002822
# std                      0.104332                    0.053045
# min                      0.000000                    0.000000
# 25%                      0.000000                    0.000000
# 50%                      0.000000                    0.000000
# 75%                      0.000000                    0.000000
# max                      1.000000                    1.000000
#
#        detailed_industry_recode_4  detailed_industry_recode_5  \
# count               199523.000000               199523.000000
# mean                     0.029992                    0.002772
# std                      0.170564                    0.052573
# min                      0.000000                    0.000000
# 25%                      0.000000                    0.000000
# 50%                      0.000000                    0.000000
# 75%                      0.000000                    0.000000
# max                      1.000000                    1.000000
#
#        detailed_industry_recode_6  detailed_industry_recode_7  \
# count               199523.000000               199523.000000
# mean                     0.002777                    0.002115
# std                      0.052621                    0.045941
# min                      0.000000                    0.000000
# 25%                      0.000000                    0.000000
# 50%                      0.000000                    0.000000
# 75%                      0.000000                    0.000000
# max                      1.000000                    1.000000
#
#        detailed_industry_recode_8  detailed_industry_recode_9  \
# count               199523.000000               199523.000000
# mean                     0.002757                    0.004977
# std                      0.052431                    0.070371
# min                      0.000000                    0.000000
# 25%                      0.000000                    0.000000
# 50%                      0.000000                    0.000000
# 75%                      0.000000                    0.000000
# max                      1.000000                    1.000000
#
#        detailed_industry_recode_10  detailed_industry_recode_11  \
# count                199523.000000                199523.000000
# mean                      0.000020                     0.008841
# std                       0.004477                     0.093611
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       0.000000                     0.000000
# max                       1.000000                     1.000000
#
#        detailed_industry_recode_12  detailed_industry_recode_13  \
# count                199523.000000                199523.000000
# mean                      0.006766                     0.004506
# std                       0.081978                     0.066974
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       0.000000                     0.000000
# max                       1.000000                     1.000000
#
#        detailed_industry_recode_14  detailed_industry_recode_15  \
# count                199523.000000                199523.000000
# mean                      0.001479                     0.002265
# std                       0.038423                     0.047542
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       0.000000                     0.000000
# max                       1.000000                     1.000000
#
#            ...        country_of_birth_self_Scotland  \
# count      ...                         199523.000000
# mean       ...                              0.000376
# std        ...                              0.019384
# min        ...                              0.000000
# 25%        ...                              0.000000
# 50%        ...                              0.000000
# 75%        ...                              0.000000
# max        ...                              1.000000
#
#        country_of_birth_self_South Korea  country_of_birth_self_Taiwan  \
# count                      199523.000000                 199523.000000
# mean                            0.002361                      0.001007
# std                             0.048529                      0.031724
# min                             0.000000                      0.000000
# 25%                             0.000000                      0.000000
# 50%                             0.000000                      0.000000
# 75%                             0.000000                      0.000000
# max                             1.000000                      1.000000
#
#        country_of_birth_self_Thailand  country_of_birth_self_Trinadad&Tobago  \
# count                   199523.000000                          199523.000000
# mean                         0.000566                               0.000331
# std                          0.023791                               0.018185
# min                          0.000000                               0.000000
# 25%                          0.000000                               0.000000
# 50%                          0.000000                               0.000000
# 75%                          0.000000                               0.000000
# max                          1.000000                               1.000000
#
#        country_of_birth_self_United-States  country_of_birth_self_Vietnam  \
# count                        199523.000000                  199523.000000
# mean                              0.887061                       0.001960
# std                               0.316519                       0.044225
# min                               0.000000                       0.000000
# 25%                               1.000000                       0.000000
# 50%                               1.000000                       0.000000
# 75%                               1.000000                       0.000000
# max                               1.000000                       1.000000
#
#        country_of_birth_self_Yugoslavia  \
# count                     199523.000000
# mean                           0.000331
# std                            0.018185
# min                            0.000000
# 25%                            0.000000
# 50%                            0.000000
# 75%                            0.000000
# max                            1.000000
#
#        citizenship_Foreign born- Not a citizen of U S   \
# count                                    199523.000000
# mean                                          0.067165
# std                                           0.250308
# min                                           0.000000
# 25%                                           0.000000
# 50%                                           0.000000
# 75%                                           0.000000
# max                                           1.000000
#
#        citizenship_Foreign born- U S citizen by naturalization  \
# count                                      199523.000000
# mean                                            0.029345
# std                                             0.168772
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        citizenship_Native- Born abroad of American Parent(s)  \
# count                                      199523.000000
# mean                                            0.008801
# std                                             0.093400
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        citizenship_Native- Born in Puerto Rico or U S Outlying  \
# count                                      199523.000000
# mean                                            0.007613
# std                                             0.086921
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        citizenship_Native- Born in the United States  \
# count                                  199523.000000
# mean                                        0.887076
# std                                         0.316501
# min                                         0.000000
# 25%                                         1.000000
# 50%                                         1.000000
# 75%                                         1.000000
# max                                         1.000000
#
#        own_business_or_self_employed_0  own_business_or_self_employed_1  \
# count                    199523.000000                    199523.000000
# mean                          0.905520                         0.013522
# std                           0.292497                         0.115497
# min                           0.000000                         0.000000
# 25%                           1.000000                         0.000000
# 50%                           1.000000                         0.000000
# 75%                           1.000000                         0.000000
# max                           1.000000                         1.000000
#
#        own_business_or_self_employed_2  \
# count                    199523.000000
# mean                          0.080958
# std                           0.272771
# min                           0.000000
# 25%                           0.000000
# 50%                           0.000000
# 75%                           0.000000
# max                           1.000000
#
#        fill_inc_questionnaire_for_veteran's_admin_No  \
# count                                  199523.000000
# mean                                        0.007984
# std                                         0.088996
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                         1.000000
#
#        fill_inc_questionnaire_for_veteran's_admin_Yes  veterans_benefits_0  \
# count                                   199523.000000        199523.000000
# mean                                         0.001960             0.237612
# std                                          0.044225             0.425621
# min                                          0.000000             0.000000
# 25%                                          0.000000             0.000000
# 50%                                          0.000000             0.000000
# 75%                                          0.000000             0.000000
# max                                          1.000000             1.000000
#
#        veterans_benefits_1  veterans_benefits_2  weeks_worked_in_year  \
# count        199523.000000        199523.000000         199523.000000
# mean              0.009944             0.752445             23.174897
# std               0.099221             0.431593             24.411488
# min               0.000000             0.000000              0.000000
# 25%               0.000000             1.000000              0.000000
# 50%               0.000000             1.000000              8.000000
# 75%               0.000000             1.000000             52.000000
# max               1.000000             1.000000             52.000000
#
#              year_94        year_95   binaryIncome
# count  199523.000000  199523.000000  199523.000000
# mean        0.500328       0.499672       0.062058
# std         0.500001       0.500001       0.241261
# min         0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000
# 50%         1.000000       0.000000       0.000000
# 75%         1.000000       1.000000       0.000000
# max         1.000000       1.000000       1.000000
#
# [8 rows x 490 columns]

# %%
y_train = X_train['binaryIncome']
y_test = X_test['binaryIncome']

X_train.drop('binaryIncome', axis=1, inplace=True)
X_test.drop('binaryIncome', axis=1, inplace=True)

# %%
# Create the RFE object and compute a cross-validated score.
svc = SVC(kernel="linear")
# The "accuracy" scoring is proportional to the number of correct
# classifications
rfecv = RFECV(estimator=svc, step=1, cv=StratifiedKFold(2),
              scoring='accuracy')
rfecv.fit(X_train, y_train)

print("Optimal number of features : %d" % rfecv.n_features_)

# Plot number of features VS. cross-validation scores
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score (nb of correct classifications)")
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
plt.show()
